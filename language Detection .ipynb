# %% [markdown]
# # Language Detection Project:

# %% [markdown]
# Using different language data we will build model which shows language name after giving text

# %% [markdown]
# ## Import required libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn import feature_extraction
from sklearn import pipeline
from sklearn import linear_model
from sklearn import metrics
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\d\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Read dataset:

# %%
df = pd.read_csv('Language Detection.csv')

# %%
#top 5 rows
df.head()
# Out:
#                                                 Text Language
# 0   Nature, in the broadest sense, is the natural...  English
# 1  "Nature" can refer to the phenomena of the phy...  English
# 2  The study of nature is a large, if not the onl...  English
# 3  Although humans are part of nature, human acti...  English
# 4  [1] The word nature is borrowed from the Old F...  English

# %%
#shape of dataset
df.shape
# Out:
# (10337, 2)

# %%
df['Language'].value_counts()
# Out:
# English       1385
# French        1014
# Spanish        819
# Portugeese     739
# Italian        698
# Russian        692
# Sweedish       676
# Malayalam      594
# Dutch          546
# Arabic         536
# Turkish        474
# German         470
# Tamil          469
# Danish         428
# Kannada        369
# Greek          365
# Hindi           63
# Name: Language, dtype: int64

# %% [markdown]
# ## Data cleaning:

# %%
corpus = []
for i in range(0, 10337):
    Text= re.sub('[^a-zA-Z]', ' ', df['Text'][i])
    # make all text in lower case
    Text = Text.lower()
    Text = Text.split()
    # stamming and remove stopwords
    ps = PorterStemmer()
    all_stopwords = stopwords.words('english')
    all_stopwords.remove('not')
    Text = [ps.stem(word) for word in Text if not word in set(all_stopwords)]
    Text = ' '.join(Text)
    corpus.append(Text)

# %%
print(corpus)
# Out:
# ['natur broadest sens natur physic materi world univers', 'natur refer phenomena physic world also life gener', 'studi natur larg not part scienc', 'although human part natur human activ often understood separ categori natur phenomena', 'word natur borrow old french natur deriv latin word natura essenti qualiti innat disposit ancient time liter meant birth', 'ancient philosophi natura mostli use latin translat greek word physi origin relat intrins characterist plant anim featur world develop accord', 'concept natur whole physic univers one sever expans origin notion began certain core applic word pre socrat philosoph though word dynam dimens especi heraclitu steadili gain currenc ever sinc', 'advent modern scientif method last sever centuri natur becam passiv realiti organ move divin law', 'industri revolut natur increasingli becam seen part realiti depriv intent intervent henc consid sacr tradit rousseau american transcendent mere decorum divin provid human histori hegel marx', 'howev vitalist vision natur closer presocrat one got reborn time especi charl darwin', 'within variou use word today natur often refer geolog wildlif', 'natur refer gener realm live plant anim case process associ inanim object way particular type thing exist chang accord weather geolog earth', 'often taken mean natur environ wilder wild anim rock forest gener thing not substanti alter human intervent persist despit human intervent', 'exampl manufactur object human interact gener not consid part natur unless qualifi exampl human natur whole natur', 'tradit concept natur thing still found today impli distinct natur artifici artifici understood brought human conscious human mind', 'depend particular context term natur might also distinguish unnatur supernatur', 'earth planet known support life natur featur subject mani field scientif research', 'within solar system third closest sun largest terrestri planet fifth largest overal', 'promin climat featur two larg polar region two rel narrow temper zone wide equatori tropic subtrop region', 'precipit vari wide locat sever metr water per year less millimetr', 'percent earth surfac cover salt water ocean', 'remaind consist contin island inhabit land northern hemispher', 'earth evolv geolog biolog process left trace origin condit', 'outer surfac divid sever gradual migrat tecton plate', 'interior remain activ thick layer plastic mantl iron fill core gener magnet field', 'iron core compos solid inner phase fluid outer phase', 'convect motion core gener electr current dynamo action turn gener geomagnet field', 'atmospher condit significantli alter origin condit presenc life form creat ecolog balanc stabil surfac condit', 'despit wide region variat climat latitud geograph factor long term averag global climat quit stabl interglaci period variat degre two averag global temperatur histor major effect ecolog balanc actual geographi earth', 'geolog scienc studi solid liquid matter constitut earth', 'field geolog encompass studi composit structur physic properti dynam histori earth materi process form move chang', 'field major academ disciplin also import miner hydrocarbon extract knowledg mitig natur hazard geotechn engin field understand past climat environ', 'geolog area evolv time rock unit deposit insert deform process chang shape locat', 'rock unit first emplac either deposit onto surfac intrud overli rock', 'deposit occur sediment settl onto surfac earth later lithifi sedimentari rock volcan materi volcan ash lava flow blanket surfac', 'igneou intrus batholith laccolith dike sill push upward overli rock crystal intrud', 'initi sequenc rock deposit rock unit deform metamorphos', 'deform typic occur result horizont shorten horizont extens side side strike slip motion', 'structur regim broadli relat converg boundari diverg boundari transform boundari respect tecton plate', 'earth estim form billion year ago solar nebula along sun planet', 'moon form roughli million year later', 'initi molten outer layer earth cool  ...

# %% [markdown]
# ## Train-Test split:

# %%
X=df.iloc[:,0]
Y=df.iloc[:,1]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X, Y, test_size = 0.20, random_state = 0)

# %%
# vectorisation
vec=feature_extraction.text.TfidfVectorizer(ngram_range=(1,2),analyzer='char')

# %% [markdown]
# ## Model Building:

# %% [markdown]
# ### Logistic Regression:

# %%
model_pipe=pipeline.Pipeline([('vec',vec),('clf',linear_model.LogisticRegression())])

# %%
model_pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('vec', TfidfVectorizer(analyzer='char', ngram_range=(1, 2))),
#                 ('clf', LogisticRegression())])

# %%
model_pipe.classes_
# Out:
# array(['Arabic', 'Danish', 'Dutch', 'English', 'French', 'German',
#        'Greek', 'Hindi', 'Italian', 'Kannada', 'Malayalam', 'Portugeese',
#        'Russian', 'Spanish', 'Sweedish', 'Tamil', 'Turkish'], dtype=object)

# %%
predict_val=model_pipe.predict(X_test)

# %% [markdown]
# ## Model Evalution:

# %%
metrics.accuracy_score(Y_test,predict_val)
# Out:
# 0.9758220502901354

# %% [markdown]
# ## Building a predictive system:

# %%
model_pipe.predict(['Nature, in the broadest sense, is the natural, physical, material world or universe.'])
# Out:
# array(['English'], dtype=object)
